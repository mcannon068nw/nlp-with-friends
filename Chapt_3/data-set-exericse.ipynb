# %%
import pandas as pd
import xml.etree.ElementTree as ET 

import spacy 
nlp = spacy.load("en_core_web_md")

from spacy import displacy
from pathlib import Path

# %% [markdown]
# # Extract Data Set

# %%
tree = ET.parse('../pubmed22n0001.xml')
root = tree.getroot()

# %%
article_count = 0
articles = []

for article in root.iter('AbstractText'):
    # print(article.tag, article.attrib,article.text)
    articles.append(article.text)
    article_count += 1

# %%
articles[2]
# Out:
# 'The distribution of blood flow to the subendocardial, medium and subepicardial layers of the left ventricular free wall was studied in anaesthetized dogs under normoxic (A), hypoxic (B) conditions and under pharmacologically induced (etafenone) coronary vasodilation (C). Regional myocardial blood flow was determined by means of the particle distribution method. In normoxia a transmural gradient of flow was observed, with the subendocardial layers receiving a significantly higher flow rate compared with the subepicardial layers. In hypoxia induced vasodilation this transmural gradient of flow was persistent. In contrast a marked redistribution of regional flow was observed under pharmacologically induced vasodilation. The transmural gradient decreased. In contrast to some findings these experiments demonstrate that a considerable vasodilatory capacity exists in all layers of the myocardium and can be utilized by drugs. The differences observed for the intramural distribution pattern of flow under hypoxia and drug induced vasodilation support the hypothesis that this pattern reflects corresponding gradients of regional myocardial metabolism.'

# %% [markdown]
# # Exploration using Chapt 3 Methods

# %%
doc = nlp(articles[2])
for token in doc:
    print(token.text, token.pos_, token.tag_, spacy.explain(token.pos_), spacy.explain(token.tag_))
# Out:
# The DET DT determiner determiner
# distribution NOUN NN noun noun, singular or mass
# of ADP IN adposition conjunction, subordinating or preposition
# blood NOUN NN noun noun, singular or mass
# flow NOUN NN noun noun, singular or mass
# to ADP IN adposition conjunction, subordinating or preposition
# the DET DT determiner determiner
# subendocardial ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# , PUNCT , punctuation punctuation mark, comma
# medium ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# and CCONJ CC coordinating conjunction conjunction, coordinating
# subepicardial ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# layers NOUN NNS noun noun, plural
# of ADP IN adposition conjunction, subordinating or preposition
# the DET DT determiner determiner
# left ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# ventricular ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# free ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# wall NOUN NN noun noun, singular or mass
# was AUX VBD auxiliary verb, past tense
# studied VERB VBN verb verb, past participle
# in ADP IN adposition conjunction, subordinating or preposition
# anaesthetized VERB VBN verb verb, past participle
# dogs NOUN NNS noun noun, plural
# under ADP IN adposition conjunction, subordinating or preposition
# normoxic PROPN NNP proper noun noun, proper singular
# ( PUNCT -LRB- punctuation left round bracket
# A PROPN NNP proper noun noun, proper singular
# ) PUNCT -RRB- punctuation right round bracket
# , PUNCT , punctuation punctuation mark, comma
# hypoxic ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# ( PUNCT -LRB- punctuation left round bracket
# B NOUN NN noun noun, singular or mass
# ) PUNCT -RRB- punctuation right round bracket
# conditions NOUN NNS noun noun, plural
# and CCONJ CC coordinating conjunction conjunction, coordinating
# under ADP IN adposition conjunction, subordinating or preposition
# pharmacologically ADV RB adverb adverb
# induced VERB VBN verb verb, past participle
# ( PUNCT -LRB- punctuation left round bracket
# etafenone NOUN NN noun noun, singular or mass
# ) PUNCT -RRB- punctuation right round bracket
# coronary ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# vasodilation NOUN NN noun noun, singular or mass
# ( PUNCT -LRB- punctuation left round bracket
# C NOUN NN noun noun, singular or mass
# ) PUNCT -RRB- punctuation right round bracket
# . PUNCT . punctuation punctuation mark, sentence closer
# Regional ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# myocardial ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# blood NOUN NN noun noun, singular or mass
# flow NOUN NN noun noun, singular or mass
# was AUX VBD auxiliary verb, past tense
# determined VERB VBN verb verb, past participle
# by ADP IN adposition conjunction, subordinating or preposition
# means NOUN NNS noun noun, plural
# of ADP IN adposition conjunction, subordinating or preposition
# the DET DT determiner determiner
# particle NOUN NN noun noun, singular or mass
# distribution NOUN NN noun noun, singular or mass
# method NOUN NN noun noun, singular or mass
# . PUNCT . punctuation punctuation mark, sentence closer
# In ADP IN adposition conjunction, subordinating or preposition
# normoxia NOUN NN noun noun, singular or mass
# a DET DT determiner determiner
# transmural ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# gradient NOUN NN noun noun, singular or mass
# of ADP IN adposition conjunction, subordinating or preposition
# flow NOUN NN noun noun, singular or mass
# was AUX VBD auxiliary verb, past tense
# observed VERB VBN verb verb, past participle
# , PUNCT , punctuation punctuation mark, comma
# with ADP IN adposition conjunction, subordinating or preposition
# the DET DT determiner determiner
# subendocardial ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# layers NOUN NNS noun noun, plural
# receiving VERB VBG verb verb, gerund or present participle
# a DET DT determiner determiner
# significantly ADV RB adverb adverb
# higher ADJ JJR adjective adjective, comparative
# flow NOUN NN noun noun, singular or mass
# rate NOUN NN noun noun, singular or mass
# compared VERB VBN verb verb, past participle
# with ADP IN adposition conjunction, subordinating or preposition
# the DET DT determiner determiner
# subepicardial ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# layers NOUN NNS noun noun, plural
# . PUNCT . punctuation punctuation mark, sentence closer
# In ADP IN adposition conjunction, subordinating or preposition
# hypoxia NOUN NN noun noun, singular or mass
# induced VERB VBN verb verb, past participle
# vasodilation NOUN NN noun noun, singular or mass
# this DET DT determiner determiner
# transmural ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# gradient NOUN NN noun noun, singular or mass
# of ADP IN adposition conjunction, subordinating or preposition
# flow NOUN NN noun noun, singular or mass
# was AUX VBD auxiliary verb, past tense
# persistent ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# . PUNCT . punctuation punctuation mark, sentence closer
# In ADP IN adposition conjunction, subordinating or preposition
# contrast NOUN NN noun noun, singular or mass
# a DET DT determiner determiner
# marked VERB VBN verb verb, past participle
# redistribution NOUN NN noun noun, singular or mass
# of ADP IN adposition conjunction, subordinating or preposition
# regional ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# flow NOUN NN noun noun, singular or mass
# was AUX VBD auxiliary verb, past tense
# observed VERB VBN verb verb, past participle
# under ADP IN adposition conjunction, subordinating or preposition
# pharmacologically ADV RB adverb adverb
# induced ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# vasodilation NOUN NN noun noun, singular or mass
# . PUNCT . punctuation punctuation mark, sentence closer
# The DET DT determiner determiner
# transmural ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# gradient NOUN NN noun noun, singular or mass
# decreased VERB VBD verb verb, past tense
# . PUNCT . punctuation punctuation mark, sentence closer
# In ADP IN adposition conjunction, subordinating or preposition
# contrast NOUN NN noun noun, singular or mass
# to ADP IN adposition conjunction, subordinating or preposition
# some DET DT determiner determiner
# findings NOUN NNS noun noun, plural
# these DET DT determiner determiner
# experiments NOUN NNS noun noun, plural
# demonstrate VERB VBP verb verb, non-3rd person singular present
# that SCONJ IN subordinating conjunction conjunction, subordinating or preposition
# a DET DT determiner determiner
# considerable ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# vasodilatory ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# capacity NOUN NN noun noun, singular or mass
# exists VERB VBZ verb verb, 3rd person singular present
# in ADP IN adposition conjunction, subordinating or preposition
# all DET DT determiner determiner
# layers NOUN NNS noun noun, plural
# of ADP IN adposition conjunction, subordinating or preposition
# the DET DT determiner determiner
# myocardium NOUN NN noun noun, singular or mass
# and CCONJ CC coordinating conjunction conjunction, coordinating
# can AUX MD auxiliary verb, modal auxiliary
# be AUX VB auxiliary verb, base form
# utilized VERB VBN verb verb, past participle
# by ADP IN adposition conjunction, subordinating or preposition
# drugs NOUN NNS noun noun, plural
# . PUNCT . punctuation punctuation mark, sentence closer
# The DET DT determiner determiner
# differences NOUN NNS noun noun, plural
# observed VERB VBD verb verb, past tense
# for ADP IN adposition conjunction, subordinating or preposition
# the DET DT determiner determiner
# intramural ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# distribution NOUN NN noun noun, singular or mass
# pattern NOUN NN noun noun, singular or mass
# of ADP IN adposition conjunction, subordinating or preposition
# flow NOUN NN noun noun, singular or mass
# under ADP IN adposition conjunction, subordinating or preposition
# hypoxia NOUN NN noun noun, singular or mass
# and CCONJ CC coordinating conjunction conjunction, coordinating
# drug NOUN NN noun noun, singular or mass
# induced VERB VBN verb verb, past participle
# vasodilation NOUN NN noun noun, singular or mass
# support NOUN NN noun noun, singular or mass
# the DET DT determiner determiner
# hypothesis NOUN NN noun noun, singular or mass
# that SCONJ IN subordinating conjunction conjunction, subordinating or preposition
# this DET DT determiner determiner
# pattern NOUN NN noun noun, singular or mass
# reflects VERB VBZ verb verb, 3rd person singular present
# corresponding VERB VBG verb verb, gerund or present participle
# gradients NOUN NNS noun noun, plural
# of ADP IN adposition conjunction, subordinating or preposition
# regional ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# myocardial ADJ JJ adjective adjective (English), other noun-modifier (Chinese)
# metabolism NOUN NN noun noun, singular or mass
# . PUNCT . punctuation punctuation mark, sentence closer

# %%
doc = nlp(articles[2])
for token in doc:
    print(token.text, token.dep_, token.head)
# Out:
# The det distribution
# distribution nsubjpass studied
# of prep distribution
# blood compound flow
# flow pobj of
# to prep flow
# the det layers
# subendocardial amod layers
# , punct subendocardial
# medium conj subendocardial
# and cc medium
# subepicardial conj medium
# layers pobj to
# of prep layers
# the det wall
# left amod ventricular
# ventricular amod wall
# free amod wall
# wall pobj of
# was auxpass studied
# studied ROOT studied
# in prep studied
# anaesthetized amod dogs
# dogs pobj in
# under prep dogs
# normoxic nmod conditions
# ( punct A
# A appos normoxic
# ) punct A
# , punct normoxic
# hypoxic amod conditions
# ( punct conditions
# B nmod conditions
# ) punct conditions
# conditions pobj under
# and cc under
# under conj under
# pharmacologically advmod induced
# induced amod vasodilation
# ( punct vasodilation
# etafenone nmod vasodilation
# ) punct vasodilation
# coronary amod vasodilation
# vasodilation pobj under
# ( punct vasodilation
# C appos vasodilation
# ) punct vasodilation
# . punct studied
# Regional amod flow
# myocardial amod flow
# blood compound flow
# flow nsubjpass determined
# was auxpass determined
# determined ROOT determined
# by agent determined
# means pobj by
# of prep means
# the det method
# particle compound distribution
# distribution compound method
# method pobj of
# . punct determined
# In prep observed
# normoxia pobj In
# a det gradient
# transmural amod gradient
# gradient nsubjpass observed
# of prep gradient
# flow pobj of
# was auxpass observed
# observed ROOT observed
# , punct observed
# with prep observed
# the det layers
# subendocardial amod layers
# layers nsubj receiving
# receiving pcomp with
# a det rate
# significantly advmod higher
# higher amod rate
# flow compound rate
# rate dobj receiving
# compared prep receiving
# with prep compared
# the det layers
# subepicardial amod layers
# layers pobj with
# . punct observed
# In prep was
# hypoxia pobj In
# induced amod vasodilation
# vasodilation pobj In
# this det gradient
# transmural amod gradient
# gradient nsubj was
# of prep gradient
# flow pobj of
# was ROOT was
# persistent acomp was
# . punct was
# In prep observed
# contrast pobj In
# a det redistribution
# marked amod redistribution
# redistribution nsubjpass observed
# of prep redistribution
# regional amod flow
# flow pobj of
# was auxpass observed
# observed ROOT observed
# under prep observed
# pharmacologically advmod induced
# induced amod vasodilation
# vasodilation pobj under
# . punct observed
# The det gradient
# transmural amod gradient
# gradient nsubj decreased
# decreased ROOT decreased
# . punct decreased
# In prep demonstrate
# contrast pobj In
# to prep contrast
# some det findings
# findings pobj to
# these det experiments
# experiments nsubj demonstrate
# demonstrate ROOT demonstrate
# that mark exists
# a det capacity
# considerable amod capacity
# vasodilatory amod capacity
# capacity nsubj exists
# exists ccomp demonstrate
# in prep exists
# all det layers
# layers pobj in
# of prep layers
# the det myocardium
# myocardium pobj of
# and cc exists
# can aux utilized
# be auxpass utilized
# utilized conj exists
# by agent utilized
# drugs pobj by
# . punct demonstrate
# The det differences
# differences nsubj observed
# observed ROOT observed
# for prep observed
# the det pattern
# intramural amod pattern
# distribution compound pattern
# pattern pobj for
# of prep pattern
# flow pobj of
# under prep flow
# hypoxia pobj under
# and cc hypoxia
# drug conj hypoxia
# induced amod support
# vasodilation compound support
# support ccomp observed
# the det hypothesis
# hypothesis dobj support
# that mark reflects
# this det pattern
# pattern nsubj reflects
# reflects acl hypothesis
# corresponding amod gradients
# gradients dobj reflects
# of prep gradients
# regional amod metabolism
# myocardial amod metabolism
# metabolism pobj of
# . punct observed

# %%
doc = nlp(articles[2])
# displacy.serve(doc, style='dep')
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e936ea0875114c2fbe45ee44a853be7c-0" class="displacy" width="27700" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">distribution</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">blood</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">flow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">subendocardial,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">medium</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">subepicardial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">layers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">left</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">ventricular</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">free</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">wall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">studied</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">anaesthetized</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">dogs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">normoxic (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">A),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">hypoxic (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">B)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">conditions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">under</tspan>
#     <tspan class="displacy-tag" d

# %%
doc = nlp(articles[1])
print(doc.ents)
for ent in doc.ents:
    print(ent, ent.label_,spacy.explain(ent.label_))
# Out:
# (214, DS, Wistar, only about 12 percent, 150 mg kg, 1.7 percent, 40 percent, one, 80 percent, 47 percent, 150 mg kg, 25 percent, 18 percent, 250-min, two, DS)
# 214 CARDINAL Numerals that do not fall under another type
# DS PERSON People, including fictional
# Wistar ORG Companies, agencies, institutions, etc.
# only about 12 percent PERCENT Percentage, including "%"
# 150 mg kg QUANTITY Measurements, as of weight or distance
# 1.7 percent PERCENT Percentage, including "%"
# 40 percent PERCENT Percentage, including "%"
# one CARDINAL Numerals that do not fall under another type
# 80 percent PERCENT Percentage, including "%"
# 47 percent PERCENT Percentage, including "%"
# 150 mg kg QUANTITY Measurements, as of weight or distance
# 25 percent PERCENT Percentage, including "%"
# 18 percent PERCENT Percentage, including "%"
# 250-min TIME Times smaller than a day
# two CARDINAL Numerals that do not fall under another type
# DS PERSON People, including fictional

# %%
doc = nlp(articles[2])
print(doc.ents)
for ent in doc.ents:
    print(ent, ent.label_,spacy.explain(ent.label_))
# Out:
# ()

# %%
doc = nlp(articles[4])
print(doc.ents)
for ent in doc.ents:
    print(ent, ent.label_,spacy.explain(ent.label_))
# Out:
# (RMI, 61 140, RMI, 61 144, RMI, 61 280, synthetized N-[8-R-dibenzo(b, f)oxepin-10-yl]-N'-methyl-, three, CPZ, CPD, CPZ, CPD, RMI, 61 140, RMI, 61 144, RMI, 61 280, CPZ)
# RMI ORG Companies, agencies, institutions, etc.
# 61 140 CARDINAL Numerals that do not fall under another type
# RMI ORG Companies, agencies, institutions, etc.
# 61 144 CARDINAL Numerals that do not fall under another type
# RMI ORG Companies, agencies, institutions, etc.
# 61 280 CARDINAL Numerals that do not fall under another type
# synthetized N-[8-R-dibenzo(b ORG Companies, agencies, institutions, etc.
# f)oxepin-10-yl]-N'-methyl- DATE Absolute or relative dates or periods
# three CARDINAL Numerals that do not fall under another type
# CPZ ORG Companies, agencies, institutions, etc.
# CPD ORG Companies, agencies, institutions, etc.
# CPZ ORG Companies, agencies, institutions, etc.
# CPD ORG Companies, agencies, institutions, etc.
# RMI ORG Companies, agencies, institutions, etc.
# 61 140 CARDINAL Numerals that do not fall under another type
# RMI ORG Companies, agencies, institutions, etc.
# 61 144 CARDINAL Numerals that do not fall under another type
# RMI ORG Companies, agencies, institutions, etc.
# 61 280 CARDINAL Numerals that do not fall under another type
# CPZ ORG Companies, agencies, institutions, etc.

# %%
articles[4]
# Out:
# "RMI 61 140, RMI 61 144 and RMI 61 280 are newly synthetized N-[8-R-dibenzo(b,f)oxepin-10-yl]-N'-methyl-piperazine-maleates which show interesting psychopharmacologic effects. This work contains the results of a study performed with these three compounds, in order to demonstrate their neuropsycholeptic activity in comparison with chloropromazine (CPZ) and chlordiazepoxide (CPD). The inhibition of motility observed in mice shows that the compounds reduce the normal spontaneous motility as well as the muscle tone. The central-depressant activity is evidenced by increased barbiturate-induced sleep and a remarkable eyelid ptosis can also be observed. Our compounds do not show any activity on electroshock just as do CPZ and CPD. As to the antipsychotic outline, our compounds show strong reduction of lethality due to amphetamine in grouped mice and a strong antiapomorphine activity. They show also an antiaggressive effect and an inhibitory activity on avoidance behaviour much stronger than CPZ. We have also found extrapyramidal effects, as catalepsy, common to many tranquillizers of the kind of the standards used by us. As for vegetative phenomena, the compounds show hypotensive dose related action ranging from moderate to strong, probably due to an a-receptor inhibition. Adrenolytic activity against lethal doses of adrenaline, antiserotonin and antihistaminic effects, as well as other actions (hypothermia, analgesia, etc.) confirm that RMI 61 140, RMI 61 144 and RMI 61 280 are endowed with pharmacologic properties similar and more potent than those of CPZ. Studies on the metabolism of brain catecholamines show that they are similar to CPZ, although with less effect on dopamine level."
